# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
t20 = pd.read_csv("t20 batting.csv")

# %%
t20.head(20)
# Out:
#     Unnamed: 0                  Player       Span  Mat Inns  NO  Runs    HS  \
# 0            0         V Kohli (INDIA)  2010-2019   75   70  20  2633   94*
# 1            1       RG Sharma (INDIA)  2007-2019  104   96  14  2633   118
# 2            2         MJ Guptill (NZ)  2009-2019   83   80   7  2436   105
# 3            3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263    75
# 4            4        BB McCullum (NZ)  2005-2015   71   70  10  2140   123
# 5            5         DA Warner (AUS)  2009-2019   76   76   8  2079  100*
# 6            6        EJG Morgan (ENG)  2009-2019   86   84  17  2002    91
# 7            7  Mohammad Shahzad (AFG)  2010-2018   65   65   3  1936  118*
# 8            8          JP Duminy (SA)  2007-2019   81   75  25  1934   96*
# 9            9       PR Stirling (IRE)  2009-2019   72   71   6  1929    91
# 10          10   Mohammad Hafeez (PAK)  2006-2018   89   86   8  1908    86
# ...

# %%
t20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2006 entries, 0 to 2005
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2006 non-null   int64
#  1   Player       2006 non-null   object
#  2   Span         2006 non-null   object
#  3   Mat          2006 non-null   int64
#  4   Inns         2006 non-null   object
#  5   NO           2006 non-null   object
#  6   Runs         2006 non-null   object
#  7   HS           2006 non-null   object
#  8   Ave          2006 non-null   object
#  9   BF           2006 non-null   object
#  10  SR           2006 non-null   object
#  11  100          2006 non-null   object
#  12  50           2006 non-null   object
#  13  0            2006 non-null   object
#  14  4s           2006 non-null   object
#  15  6s           2006 non-null   object
#  16  Unnamed: 15  0 non-null      float64
# dtypes: float64(1), int64(2), object(14)
# memory usage: 266.6+ KB

# %%
t20.shape
# Out:
# (2006, 17)

# %%
t20.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS',
#        'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s', 'Unnamed: 15'],
#       dtype='object')

# %%
t20.describe()
# Out:
#         Unnamed: 0          Mat  Unnamed: 15
# count  2006.000000  2006.000000          0.0
# mean     24.434197    11.231805          NaN
# std      14.463176    14.923332          NaN
# min       0.000000     1.000000          NaN
# 25%      12.000000     3.000000          NaN
# 50%      24.000000     5.000000          NaN
# 75%      37.000000    13.000000          NaN
# max      49.000000   111.000000          NaN

# %%
t20=t20.drop(["Unnamed: 0","Unnamed: 15"],axis=1)

# %%
t20.head(20)
# Out:
#                     Player       Span  Mat Inns  NO  Runs    HS    Ave    BF  \
# 0          V Kohli (INDIA)  2010-2019   75   70  20  2633   94*  52.66  1907
# 1        RG Sharma (INDIA)  2007-2019  104   96  14  2633   118   32.1  1905
# 2          MJ Guptill (NZ)  2009-2019   83   80   7  2436   105  33.36  1810
# 3   Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263    75  30.58  1824
# 4         BB McCullum (NZ)  2005-2015   71   70  10  2140   123  35.66  1571
# 5          DA Warner (AUS)  2009-2019   76   76   8  2079  100*  30.57  1476
# 6         EJG Morgan (ENG)  2009-2019   86   84  17  2002    91  29.88  1475
# 7   Mohammad Shahzad (AFG)  2010-2018   65   65   3  1936  118*  31.22  1436
# 8           JP Duminy (SA)  2007-2019   81   75  25  1934   96*  38.68  1532
# 9        PR Stirling (IRE)  2009-2019   72   71   6  1929    91  29.67  1401
# 10   Mohammad Hafeez (PAK)  2006-2018   89   86   8  1908    86  24.46  1643
# ...

# %%
temp=t20["Player"].str.split("(",expand=True)

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2006 entries, 0 to 2005
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2006 non-null   object
#  1   1       2006 non-null   object
#  2   2       4 non-null      object
# dtypes: object(3)
# memory usage: 47.1+ KB

# %%
temp
# Out:
#                     0         1     2
# 0            V Kohli     INDIA)  None
# 1          RG Sharma     INDIA)  None
# 2         MJ Guptill        NZ)  None
# 3       Shoaib Malik   ICC/PAK)  None
# 4        BB McCullum        NZ)  None
# ...               ...       ...   ...
# 2001  SG Whittingham      SCOT)  None
# 2002     LJ Woodcock        NZ)  None
# 2003      Zamir Khan       AFG)  None
# 2004        S Zargar       Mex)  None
# 2005    Ziaur Rahman       AFG)  None
#
# [2006 rows x 3 columns]

# %%
anamoly=temp[temp[2].notna()]

# %%
anamoly
# Out:
#                     0    1     2
# 1084     Rameez Raja   2)   PAK)
# 1299  Mohammad Nawaz   3)   PAK)
# 1357     Aftab Ahmed   2)   DEN)
# 1795      Imran Khan   1)   PAK)

# %%
anamoly[1]=anamoly.loc[anamoly[2].notna(),2]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\3591957652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anamoly[1]=anamoly.loc[anamoly[2].notna(),2]

# %%
temp.update(anamoly)

# %%
temp
# Out:
#                     0         1     2
# 0            V Kohli     INDIA)  None
# 1          RG Sharma     INDIA)  None
# 2         MJ Guptill        NZ)  None
# 3       Shoaib Malik   ICC/PAK)  None
# 4        BB McCullum        NZ)  None
# ...               ...       ...   ...
# 2001  SG Whittingham      SCOT)  None
# 2002     LJ Woodcock        NZ)  None
# 2003      Zamir Khan       AFG)  None
# 2004        S Zargar       Mex)  None
# 2005    Ziaur Rahman       AFG)  None
#
# [2006 rows x 3 columns]

# %%
temp[temp[2].notna()]
# Out:
#                     0     1     2
# 1084     Rameez Raja   PAK)  PAK)
# 1299  Mohammad Nawaz   PAK)  PAK)
# 1357     Aftab Ahmed   DEN)  DEN)
# 1795      Imran Khan   PAK)  PAK)

# %%
temp=temp.drop(2,axis=1)

# %%
temp
# Out:
#                     0         1     2
# 0            V Kohli     INDIA)  None
# 1          RG Sharma     INDIA)  None
# 2         MJ Guptill        NZ)  None
# 3       Shoaib Malik   ICC/PAK)  None
# 4        BB McCullum        NZ)  None
# ...               ...       ...   ...
# 2001  SG Whittingham      SCOT)  None
# 2002     LJ Woodcock        NZ)  None
# 2003      Zamir Khan       AFG)  None
# 2004        S Zargar       Mex)  None
# 2005    Ziaur Rahman       AFG)  None
#
# [2006 rows x 3 columns]

# %%
t20["Player"]=temp[0]

# %%
t20
# Out:
#                Player       Span  Mat Inns  NO  Runs   HS    Ave    BF  \
# 0            V Kohli   2010-2019   75   70  20  2633  94*  52.66  1907
# 1          RG Sharma   2007-2019  104   96  14  2633  118   32.1  1905
# 2         MJ Guptill   2009-2019   83   80   7  2436  105  33.36  1810
# 3       Shoaib Malik   2006-2019  111  104  30  2263   75  30.58  1824
# 4        BB McCullum   2005-2015   71   70  10  2140  123  35.66  1571
# ...               ...        ...  ...  ...  ..   ...  ...    ...   ...
# 2001  SG Whittingham   2018-2018    3    -   -     -    -      -     -
# 2002     LJ Woodcock   2010-2011    3    -   -     -    -      -     -
# 2003      Zamir Khan   2012-2012    1    -   -     -    -      -     -
# 2004        S Zargar   2019-2019    1    -   -     -    -      -     -
# 2005    Ziaur Rahman   2019-2019    1    -   -     -    -      -     -
#
#           SR 100  50  0   4s   6s
# 0     138.07   0  24  2  247   71
# 1     138.21   4  19  6  234  120
# ...

# %%
region = temp[1]

# %%
region
# Out:
# 0         INDIA)
# 1         INDIA)
# 2            NZ)
# 3       ICC/PAK)
# 4            NZ)
#           ...
# 2001       SCOT)
# 2002         NZ)
# 2003        AFG)
# 2004        Mex)
# 2005        AFG)
# Name: 1, Length: 2006, dtype: object

# %%
region=region.str.split("/",expand=True)

# %%
region
# Out:
#            0     1     2
# 0     INDIA)  None  None
# 1     INDIA)  None  None
# 2        NZ)  None  None
# 3        ICC  PAK)  None
# 4        NZ)  None  None
# ...      ...   ...   ...
# 2001   SCOT)  None  None
# 2002     NZ)  None  None
# 2003    AFG)  None  None
# 2004    Mex)  None  None
# 2005    AFG)  None  None
#
# [2006 rows x 3 columns]

# %%
region[2].unique()
# Out:
# array([None, 'World)', 'NZ)'], dtype=object)

# %%
region2=region[region[1].notna()]

# %%
region2
# Out:
#           0       1       2
# 3       ICC    PAK)    None
# 20    BDESH     ICC  World)
# 33      ICC    PAK)    None
# 37       SA  World)    None
# 39       SA  World)    None
# 40       SA  World)    None
# 48      ICC      SL  World)
# 109      WI  World)    None
# 110     ENG  World)    None
# 136     HKG     NZ)    None
# 138     AUS  World)    None
# 149      NL     SA)    None
# 169     ENG    IRE)    None
# 174     ICC  INDIA)    None
# 191     AUS     ICC     NZ)
# 196     ENG    ICC)    None
# 358     USA     WI)    None
# 374      NZ  World)    None
# 405     AFG    ICC)    None
# 448     USA     WI)    None
# 620     AUS  World)    None
# 711     ENG    IRE)    None
# 859      WI  World)    None
# 890     AUS  World)    None
# 1044    AFG    GER)    None
# 1083    ICC     NZ)    None
# 1097    ICC  NEPAL)    None
# 1113     SA  World)    None
# 1115    AUS     NL)    None
# 1156     SA  World)    None
# 1807    ENG    ICC)    None

# %%
icc = region[region[0]=="ICC"]

# %%
icc[0]=icc[1]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\2224204669.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   icc[0]=icc[1]

# %%
icc
# Out:
#            0       1       2
# 3       PAK)    PAK)    None
# 33      PAK)    PAK)    None
# 48        SL      SL  World)
# 174   INDIA)  INDIA)    None
# 1083     NZ)     NZ)    None
# 1097  NEPAL)  NEPAL)    None

# %%
icc2 = region[region[1]=="ICC"]

# %%
icc2
# Out:
#          0    1       2
# 20   BDESH  ICC  World)
# 191    AUS  ICC     NZ)

# %%
region.update(icc)

# %%
region[region[0]=="ICC"]
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %%
region
# Out:
#            0     1     2
# 0     INDIA)  None  None
# 1     INDIA)  None  None
# 2        NZ)  None  None
# 3       PAK)  PAK)  None
# 4        NZ)  None  None
# ...      ...   ...   ...
# 2001   SCOT)  None  None
# 2002     NZ)  None  None
# 2003    AFG)  None  None
# 2004    Mex)  None  None
# 2005    AFG)  None  None
#
# [2006 rows x 3 columns]

# %%
region=region.drop(2,axis=1)

# %%
region=region.drop(1,axis=1)

# %%
region.isnull().sum()
# Out:
# 0    0
# dtype: int64

# %%
region=region[0].str.split(")",expand=True)

# %%
t20["Country"] = region[0]

# %%
t20["Country"].unique()
# Out:
# array(['INDIA', 'NZ', 'PAK', 'AUS', 'ENG', 'AFG', 'SA', 'IRE', 'SL',
#        'ZIM', 'WI', 'BDESH', 'SCOT', 'NL', 'UAE', 'NEPAL', 'KENYA', 'PNG',
#        'OMAN', 'HKG', 'CAN', 'QAT', 'MAL', 'SGP', 'NAM', 'VAN', 'JER',
#        'KUW', 'USA', 'BMUDA', 'Mald', 'Moz', 'CZK-R', 'Aut', 'ITA', 'GUE',
#        'ESP', 'GER', 'DEN', 'Mex', 'Fin', 'BAH', 'ROM', 'UGA', 'MWI',
#        'PNM', 'Saudi', 'THAI', 'PORT', 'GIBR', 'NGA', 'Botsw', '', 'LUX',
#        'Serb', 'Blz', 'Caym', 'CRC', 'NOR', 'Arg', 'Samoa', 'MALTA',
#        'Peru', 'Chile', 'Belg', 'PHI', 'BHU', 'Ghana', 'TKY'],
#       dtype=object)

# %%
t20
# Out:
#                Player       Span  Mat Inns  NO  Runs   HS    Ave    BF  \
# 0            V Kohli   2010-2019   75   70  20  2633  94*  52.66  1907
# 1          RG Sharma   2007-2019  104   96  14  2633  118   32.1  1905
# 2         MJ Guptill   2009-2019   83   80   7  2436  105  33.36  1810
# 3       Shoaib Malik   2006-2019  111  104  30  2263   75  30.58  1824
# 4        BB McCullum   2005-2015   71   70  10  2140  123  35.66  1571
# ...               ...        ...  ...  ...  ..   ...  ...    ...   ...
# 2001  SG Whittingham   2018-2018    3    -   -     -    -      -     -
# 2002     LJ Woodcock   2010-2011    3    -   -     -    -      -     -
# 2003      Zamir Khan   2012-2012    1    -   -     -    -      -     -
# 2004        S Zargar   2019-2019    1    -   -     -    -      -     -
# 2005    Ziaur Rahman   2019-2019    1    -   -     -    -      -     -
#
#           SR 100  50  0   4s   6s Country
# 0     138.07   0  24  2  247   71   INDIA
# ...

# %%
t20["Span"]=t20["Span"].astype(str)

# %%
years = t20["Span"].str.split("-",expand=True)

# %%
years
# Out:
#          0     1
# 0     2010  2019
# 1     2007  2019
# 2     2009  2019
# 3     2006  2019
# 4     2005  2015
# ...    ...   ...
# 2001  2018  2018
# 2002  2010  2011
# 2003  2012  2012
# 2004  2019  2019
# 2005  2019  2019
#
# [2006 rows x 2 columns]

# %%
t20["Start year"]=years[0]
t20["End year"]=years[1]

# %%
t20
# Out:
#                Player       Span  Mat Inns  NO  Runs   HS    Ave    BF  \
# 0            V Kohli   2010-2019   75   70  20  2633  94*  52.66  1907
# 1          RG Sharma   2007-2019  104   96  14  2633  118   32.1  1905
# 2         MJ Guptill   2009-2019   83   80   7  2436  105  33.36  1810
# 3       Shoaib Malik   2006-2019  111  104  30  2263   75  30.58  1824
# 4        BB McCullum   2005-2015   71   70  10  2140  123  35.66  1571
# ...               ...        ...  ...  ...  ..   ...  ...    ...   ...
# 2001  SG Whittingham   2018-2018    3    -   -     -    -      -     -
# 2002     LJ Woodcock   2010-2011    3    -   -     -    -      -     -
# 2003      Zamir Khan   2012-2012    1    -   -     -    -      -     -
# 2004        S Zargar   2019-2019    1    -   -     -    -      -     -
# 2005    Ziaur Rahman   2019-2019    1    -   -     -    -      -     -
#
#           SR 100  50  0   4s   6s Country Start year End year
# ...

# %%
t20.replace("-",0,inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\2282644549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t20.replace("-",0,inplace=True)

# %%
t20
# Out:
#                Player       Span  Mat Inns  NO  Runs   HS    Ave    BF  \
# 0            V Kohli   2010-2019   75   70  20  2633  94*  52.66  1907
# 1          RG Sharma   2007-2019  104   96  14  2633  118   32.1  1905
# 2         MJ Guptill   2009-2019   83   80   7  2436  105  33.36  1810
# 3       Shoaib Malik   2006-2019  111  104  30  2263   75  30.58  1824
# 4        BB McCullum   2005-2015   71   70  10  2140  123  35.66  1571
# ...               ...        ...  ...  ...  ..   ...  ...    ...   ...
# 2001  SG Whittingham   2018-2018    3    0   0     0    0      0     0
# 2002     LJ Woodcock   2010-2011    3    0   0     0    0      0     0
# 2003      Zamir Khan   2012-2012    1    0   0     0    0      0     0
# 2004        S Zargar   2019-2019    1    0   0     0    0      0     0
# 2005    Ziaur Rahman   2019-2019    1    0   0     0    0      0     0
#
#           SR 100  50  0   4s   6s Country Start year End year
# ...

# %%
t20 = t20.drop("Span",axis=1)

# %%
t20
# Out:
#                Player  Mat Inns  NO  Runs   HS    Ave    BF      SR 100  50  \
# 0            V Kohli    75   70  20  2633  94*  52.66  1907  138.07   0  24
# 1          RG Sharma   104   96  14  2633  118   32.1  1905  138.21   4  19
# 2         MJ Guptill    83   80   7  2436  105  33.36  1810  134.58   2  15
# 3       Shoaib Malik   111  104  30  2263   75  30.58  1824  124.06   0   7
# 4        BB McCullum    71   70  10  2140  123  35.66  1571  136.21   2  13
# ...               ...  ...  ...  ..   ...  ...    ...   ...     ...  ..  ..
# 2001  SG Whittingham     3    -   -     -    -      -     -       -   -   -
# 2002     LJ Woodcock     3    -   -     -    -      -     -       -   -   -
# 2003      Zamir Khan     1    -   -     -    -      -     -       -   -   -
# 2004        S Zargar     1    -   -     -    -      -     -       -   -   -
# 2005    Ziaur Rahman     1    -   -     -    -      -     -       -   -   -
#
#       0   4s   6s Country Start year End year
# ...

# %%
t20["Country"].unique()
# Out:
# array(['INDIA', 'NZ', 'PAK', 'AUS', 'ENG', 'AFG', 'SA', 'IRE', 'SL',
#        'ZIM', 'WI', 'BDESH', 'SCOT', 'NL', 'UAE', 'NEPAL', 'KENYA', 'PNG',
#        'OMAN', 'HKG', 'CAN', 'QAT', 'MAL', 'SGP', 'NAM', 'VAN', 'JER',
#        'KUW', 'USA', 'BMUDA', 'Mald', 'Moz', 'CZK-R', 'Aut', 'ITA', 'GUE',
#        'ESP', 'GER', 'DEN', 'Mex', 'Fin', 'BAH', 'ROM', 'UGA', 'MWI',
#        'PNM', 'Saudi', 'THAI', 'PORT', 'GIBR', 'NGA', 'Botsw', '', 'LUX',
#        'Serb', 'Blz', 'Caym', 'CRC', 'NOR', 'Arg', 'Samoa', 'MALTA',
#        'Peru', 'Chile', 'Belg', 'PHI', 'BHU', 'Ghana', 'TKY'],
#       dtype=object)

# %%
t20=t20[t20["Country"]!='']

# %%
t20.shape
# Out:
# (1967, 17)

# %%
t20["Country"].unique()
# Out:
# array(['INDIA', 'NZ', 'PAK', 'AUS', 'ENG', 'AFG', 'SA', 'IRE', 'SL',
#        'ZIM', 'WI', 'BDESH', 'SCOT', 'NL', 'UAE', 'NEPAL', 'KENYA', 'PNG',
#        'OMAN', 'HKG', 'CAN', 'QAT', 'MAL', 'SGP', 'NAM', 'VAN', 'JER',
#        'KUW', 'USA', 'BMUDA', 'Mald', 'Moz', 'CZK-R', 'Aut', 'ITA', 'GUE',
#        'ESP', 'GER', 'DEN', 'Mex', 'Fin', 'BAH', 'ROM', 'UGA', 'MWI',
#        'PNM', 'Saudi', 'THAI', 'PORT', 'GIBR', 'NGA', 'Botsw', 'LUX',
#        'Serb', 'Blz', 'Caym', 'CRC', 'NOR', 'Arg', 'Samoa', 'MALTA',
#        'Peru', 'Chile', 'Belg', 'PHI', 'BHU', 'Ghana', 'TKY'],
#       dtype=object)

# %%
t20.columns
# Out:
# Index(['Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100',
#        '50', '0', '4s', '6s', 'Country', 'Start year', 'End year'],
#       dtype='object')

# %%
t20["Mat"] = t20["Mat"].astype(int)
t20["Inns"] = t20["Inns"].astype(int)
t20["NO"] = t20["NO"].astype(int)
t20["Runs"] = t20["Runs"].astype(int)
t20["BF"] = t20["BF"].astype(int)
t20["100"] = t20["100"].astype(int)
t20["50"] = t20["50"].astype(int)
t20["0"] = t20["0"].astype(int)
t20["4s"] = t20["4s"].astype(int)
t20["6s"] = t20["6s"].astype(int)
t20["Ave"] = t20["Ave"].astype(float)
t20["SR"] = t20["SR"].astype(float)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\2927122955.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t20["Mat"] = t20["Mat"].astype(int)
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\2927122955.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t20["Inns"] = t20["Inns"].astype(int)
# C:\Users\User\AppData\Local\Temp\ipykernel_10824\2927122955.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
t20 = t20[t20["Runs"]>=500]

# %%
t20
# Out:
#                Player  Mat  Inns  NO  Runs   HS    Ave    BF      SR  100  50  \
# 0            V Kohli    75    70  20  2633  94*  52.66  1907  138.07    0  24
# 1          RG Sharma   104    96  14  2633  118  32.10  1905  138.21    4  19
# 2         MJ Guptill    83    80   7  2436  105  33.36  1810  134.58    2  15
# 3       Shoaib Malik   111   104  30  2263   75  30.58  1824  124.06    0   7
# 4        BB McCullum    71    70  10  2140  123  35.66  1571  136.21    2  13
# ..                ...  ...   ...  ..   ...  ...    ...   ...     ...  ...  ..
# 124      F Behardien    38    30  14   518  64*  32.37   404  128.21    0   1
# 125        V Sibanda    26    26   1   511   59  20.44   503  101.59    0   1
# 126  Noor Ali Zadran    20    20   1   506   63  26.63   497  101.81    0   3
# 127    Nawroz Mangal    32    32   4   505  65*  18.03   453  111.47    0   2
# 128      Imran Nazir    25    24   1   500   72  21.73   370  135.13    0   3
#
# ...

# %%
t20.to_excel("T20 batting cleaned.xlsx",index=False)
